# %%
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import norm
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import   ttest_1samp, ttest_ind

# %%
145/235
# Out:
# 0.6170212765957447

# %%
(29/235)+(94/235)+0
# Out:
# 0.5234042553191489

# %%
45/235
# Out:
# 0.19148936170212766

# %%
45/145
# Out:
# 0.3103448275862069

# %%
80/145
# Out:
# 0.5517241379310345

# %%
mu = 5
sigma = 1.5
x=3.17
z=(x-mu)/sigma
p=stats.norm.cdf(z)
print ('proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is %1.4f' %p)
# Out:
# proportion of the gunny bags have a breaking strength less than 3.17 kg per sq cm is 0.1112

# %%
lessthan3=norm.cdf(x=3.17, loc=5, scale=1.5)
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(0,10,0.001)
ax.plot(x, norm.pdf(x,loc=5,scale=1.5))
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
# for fill_between
px=np.arange(0,3.17,0.01)
ax.set_ylim(0,0.3)
ax.fill_between(px,norm.pdf(px,loc=5,scale=1.5),alpha=0.5, color='g')
# for text
ax.text(0,0.02,round(lessthan3,2), fontsize=20)
plt.show()

# %%
lessthan3=norm.cdf(x=3.6, loc=5, scale=1.5)
fig, ax = plt.subplots()
# for distribution curve
x= np.arange(0,10,0.001)
ax.plot(x, norm.pdf(x,loc=5,scale=1.5))
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
# for fill_between
px=np.arange(3.16,10,0.01)
ax.set_ylim(0,0.3)
ax.fill_between(px,norm.pdf(px,loc=5,scale=1.5),alpha=0.5, color='g')
# for text
ax.text(0,0.02,1-round(lessthan3,2), fontsize=20)
plt.show()

# %%
mu = 5
sigma = 1.5
x=3.6
z=(x-mu)/sigma
p=1-stats.norm.cdf(z)
print(p)
print ('proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm. is %1.4f' %p)
# Out:
# 0.8246760551477705
# proportion of the gunny bags have a breaking strength at least 3.6 kg per sq cm. is 0.8247

# %%
mu = 5
sigma = 1.5
x1 = 5
x2 = 5.5

p1 = norm.cdf(x1,mu,sigma) 
p2 = norm.cdf(x2,mu,sigma) 
print("proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm. is  ", abs(p2-p1))

mu = 5
sigma = 1.5
x1 = 5
x2 = 5.5

x_2 = np.arange(x2,11, 0.001)
x_1 = np.arange(-1,x1, 0.001)
x_all = np.arange(-1,11, 0.001)
y_1 = norm.pdf(x_1,mu,sigma)
y_2 = norm.pdf(x_2,mu,sigma)
y_all = norm.pdf(x_all,mu,sigma)


# fig, ax = plt.subplots()
# ax.plot(x_all,y_all)
# ax.fill_between(x_1,y_1,0, alpha=0.3, color='r')
# ax.fill_between(x_2,y_2,0, alpha=0.3, color='r')
# ax.fill_between(x_all,y_all,0, alpha=0.1)
# ax.set_xlim([-1,11])
# ax.set_xlabel('breaking strength of gunny bags in kg per cm')
# ax.set_yticklabels([])
# ax.set_title('')
# plt.show()


fig, ax = plt.subplots()
# for distribution curve
x= np.arange(0,10,0.001)
ax.plot(x, norm.pdf(x,loc=5,scale=1.5))
ax.set_xlabel('x')
ax.set_ylabel('pdf(x)')
ax.grid(True)
px=np.arange(5,5.5,0.01)
ax.set_ylim(0,0.3)
ax.fill_between(px,norm.pdf(px,loc=5,scale=1.5),alpha=0.5, color='g')
pro= p2-p1
ax.text(0.2,0.02,round(pro,2), fontsize=20)
plt.show()
# Out:
# proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm. is   0.13055865981823633

# %%
mu = 5
sigma = 1.5
x1 = 3
x2 = 7.5
# Finding Required probability 
prob = 1 + norm.cdf(x1,mu,sigma) - norm.cdf(x2,mu,sigma) 
print("proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm. is  ", prob)
# Out:
# proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm. is   0.13900157199868257

# %%
mu = 5
sigma = 1.5
x1 = 3
x2 = 7.5

x_2 = np.arange(x2,11, 0.001)
x_1 = np.arange(-1,x1, 0.001)
x_all = np.arange(-1,11, 0.001)
y_1 = norm.pdf(x_1,mu,sigma)
y_2 = norm.pdf(x_2,mu,sigma)
y_all = norm.pdf(x_all,mu,sigma)


fig, ax = plt.subplots()
ax.plot(x_all,y_all)
ax.fill_between(x_1,y_1,0, alpha=0.3, color='g')
ax.fill_between(x_2,y_2,0, alpha=0.3, color='g')
ax.fill_between(x_all,y_all,0, alpha=0.1)
ax.set_xlim([-1,11])
ax.set_xlabel('breaking strength of gunny bags in kg per cm')
ax.set_yticklabels([])
ax.set_title('Normal distribution')
plt.show()


# plt.plot(density["x"], density["pdf"])
# plt.axvline(x=1300, c="r")
# x1=np.linspace(1300, density["x"].max(), 50)
# plt.fill_between(x1, norm.pdf(x1, mu, sigma), color='r')
# plt.xlabel("Score")
# plt.ylabel("Probability")
# plt.title("Normal distribution")
# plt.show()

# %%
mu = 77
sigma = 8.5
x=85
z=(x-mu)/sigma
p=stats.norm.cdf(z)
print(p)
print ('probability that a randomly chosen student gets a grade below 85 on this exam is %1.4f' %p)
# Out:
# 0.8266927837484748
# probability that a randomly chosen student gets a grade below 85 on this exam is 0.8267

# %%
mu = 77
sigma = 8.5
x=75
z=abs(x-mu)/sigma
print(1-z)
# Out:
# 0.7647058823529411

# %%
mu = 77
sigma = 8.5
x1 = 65
x2 = 87

p1 = norm.cdf(x1,mu,sigma) 
p2 = norm.cdf(x2,mu,sigma) 
print("probability that a randomly selected student scores between 65 and 87 is  ", abs(p2-p1))
# Out:
# probability that a randomly selected student scores between 65 and 87 is   0.8012869336779058

# %%
mu=77
sigma=8.5
Prob = stats.norm.ppf(0.25, loc = 77, scale = sigma)
print(Prob)
# Out:
# 71.2668371233333

# %%
df=pd.read_csv("Zingaro_Company.csv")
df.head()
# Out:
#    Unpolished   Treated and Polished
# 0   164.481713            133.209393
# 1   154.307045            138.482771
# 2   129.861048            159.665201
# 3   159.096184            145.663528
# 4   135.256748            136.789227

# %%
t_statistic, p_value = ttest_1samp(df['Unpolished '], 150)
print('One sample t test \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
alpha_value = 0.05 # Level of significance
print('Level of significance: %.2f' %alpha_value)
if p_value < alpha_value: 
    print('We have evidence to reject the null hypothesis since p value < Level of significance')
else:
    print('We have no evidence to reject the null hypothesis since p value > Level of significance') 

print ("Our one-sample t-test p-value=", p_value)
# Out:
# One sample t test
# t statistic: -4.164629601426757 p value: 8.342573994839304e-05
# Level of significance: 0.05
# We have evidence to reject the null hypothesis since p value < Level of significance
# Our one-sample t-test p-value= 8.342573994839304e-05

# %%
df.describe()
# Out:
#        Unpolished   Treated and Polished
# count    75.000000             75.000000
# mean    134.110527            147.788117
# std      33.041804             15.587355
# min      48.406838            107.524167
# 25%     115.329753            138.268300
# 50%     135.597121            145.721322
# 75%     158.215098            157.373318
# max     200.161313            192.272856

# %%
sns.histplot(df['Unpolished '], kde=True)
# Out:
# <AxesSubplot: xlabel='Unpolished ', ylabel='Count'>

# %%
sns.histplot(df['Treated and Polished'], kde=True)
# Out:
# <AxesSubplot: xlabel='Treated and Polished', ylabel='Count'>

# %%
u_mean = df['Unpolished '].mean()
u_std = df['Unpolished '].std()
n = df['Unpolished '].count()
t_stat = (u_mean - 150) / (u_std / (n**0.5))
p_value = stats.t.sf(abs(t_stat), n-1)
print(p_value)
if p_value < 0.05:
    print("Zingaro is justified in thinking that the unpolished stones may not be suitable for printing.")
else:
    print("Zingaro is not justified in thinking that the unpolished stones may not be suitable for printing.")
# Out:
# 4.171286997419643e-05
# Zingaro is justified in thinking that the unpolished stones may not be suitable for printing.

# %%
p_mean = df['Treated and Polished'].mean()
u_mean = df['Unpolished '].mean()
p_std = df['Treated and Polished'].std()
u_std = df['Unpolished '].std()
n1 = df['Treated and Polished'].count()
n2 = df['Unpolished '].count()
sp = ((n1-1)*p_std**2 + (n2-1)*u_std**2) / (n1+n2-2)
t_stat = (p_mean - u_mean) / (sp * ((1/n1) + (1/n2)))**0.5
p_value = stats.t.sf(abs(t_stat), n1+n2-2)

# t_statistic1, p_value1  = ttest_ind(df['Unpolished '],df['Treated and Polished'])
# print('tstat',t_statistic1)    
# print('P Value',p_value1)  
print(p_value)

# mu, sigma=5, 1.3
# x_bar=5.25
# test_stat=(x_bar - mu)/(sigma/np.sqrt(45))
# test_stat

if p_value < 0.05:
    print("The mean hardness of the polished and unpolished stones is different.")
else:
    print("The mean hardness of the polished and unpolished stones is the same.")
# Out:
# 0.0007327575097314177
# The mean hardness of the polished and unpolished stones is different.

# %%
# Importing library
import pandas as pd
import scipy.stats as stats
#Reading the data
df1= pd.read_csv("Aquarius_gym.csv")
#Change to series
x=df1["Before"]
y=df1["After"]+5
#Running paired t-test
stats.ttest_rel(x, y, alternative="less")
# Out:
# TtestResult(statistic=-36.73038540665224, pvalue=8.7328623006375e-60, df=99)

# %%
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA
xls=pd.ExcelFile("Dental Hardness data.xlsx")
df2=pd.read_excel(xls,"Data")
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
df2.Method=pd.Categorical(df2.Method)
df2.Alloy=pd.Categorical(df2.Alloy)
df2.Dentist=pd.Categorical(df2.Dentist)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     category
#  1   Method    90 non-null     category
#  2   Alloy     90 non-null     category
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: category(3), int64(2)
# memory usage: 2.3 KB

# %%
df2['Method'].unique()
# Out:
# [1, 2, 3]
# Categories (3, int64): [1, 2, 3]

# %%
formula='Response ~ C(Method) + C(Alloy)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#              df        sum_sq        mean_sq          F        PR(>F)
# C(Method)   2.0  5.934275e+05  296713.744444  21.409848  2.845744e-08
# C(Alloy)    1.0  1.058155e+05  105815.511111   7.635285  6.999664e-03
# Residual   86.0  1.191853e+06   13858.750646        NaN           NaN

# %%
sns.pointplot(x='Method', y='Response', data=df2, hue='Alloy', ci=None)
# Out:
# C:\Users\harikrishnan.m\AppData\Local\Temp\ipykernel_35172\3550571466.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.pointplot(x='Method', y='Response', data=df2, hue='Alloy', ci=None)
# <AxesSubplot: xlabel='Method', ylabel='Response'>

# %%
formula='Response ~ C(Method) + C(Alloy)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#              df        sum_sq        mean_sq          F        PR(>F)
# C(Method)   2.0  5.934275e+05  296713.744444  21.409848  2.845744e-08
# C(Alloy)    1.0  1.058155e+05  105815.511111   7.635285  6.999664e-03
# Residual   86.0  1.191853e+06   13858.750646        NaN           NaN

# %%
formula='Response ~ C(Dentist) + C(Method)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#               df        sum_sq        mean_sq          F        PR(>F)
# C(Dentist)   4.0  1.577946e+05   39448.638889   2.872456  2.784543e-02
# C(Method)    2.0  5.934275e+05  296713.744444  21.605240  2.794351e-08
# Residual    83.0  1.139874e+06   13733.415797        NaN           NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=df2, hue='Method')
# Out:
# <AxesSubplot: xlabel='Dentist', ylabel='Response'>

# %%
#pd.crosstab(df2['Dentist'], df2['Method']).plot(kind='bar', stacked=True)
#df2.plot(x='Dentist', y='Response', stacked = True)
# Out:
# <AxesSubplot: xlabel='Dentist'>

# %%
xls1=pd.ExcelFile("AAC6EF00.xlsx")
df3=pd.read_excel(xls1,"Alloy1")

# %%
formula='Response ~ C(Dentist) + C(Method)'
model=ols(formula, df3).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq       mean_sq         F    PR(>F)
# C(Dentist)   4.0  106683.688889  26670.922222  2.591255  0.051875
# C(Method)    2.0  148472.177778  74236.088889  7.212522  0.002211
# Residual    38.0  391121.377778  10292.667836       NaN       NaN

# %%
formula='Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model=ols(formula, df3).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq       mean_sq          F    PR(>F)
# C(Dentist)             4.0  106683.688889  26670.922222   3.899638  0.011484
# C(Method)              2.0  148472.177778  74236.088889  10.854287  0.000284
# C(Dentist):C(Method)   8.0  185941.377778  23242.672222   3.398383  0.006793
# Residual              30.0  205180.000000   6839.333333        NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=df3, hue='Method', errorbar=None)
# Out:
# <AxesSubplot: xlabel='Dentist', ylabel='Response'>

# %%
xls1=pd.ExcelFile("AAC6EF00.xlsx")
df4=pd.read_excel(xls1,"Alloy2")

# %%
formula='Response ~ C(Dentist) + C(Method)'
model=ols(formula, df4).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#               df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)   4.0   56797.911111   14199.477778   0.926215  0.458933
# C(Method)    2.0  499640.400000  249820.200000  16.295479  0.000008
# Residual    38.0  582564.488889   15330.644444        NaN       NaN

# %%
formula='Response ~ C(Dentist) + C(Method) + C(Dentist):C(Method)'
model=ols(formula, df4).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F    PR(>F)
# C(Dentist)             4.0   56797.911111   14199.477778   1.106152  0.371833
# C(Method)              2.0  499640.400000  249820.200000  19.461218  0.000004
# C(Dentist):C(Method)   8.0  197459.822222   24682.477778   1.922787  0.093234
# Residual              30.0  385104.666667   12836.822222        NaN       NaN

# %%
sns.pointplot(x='Dentist', y='Response', data=df4, hue='Method', errorbar=None)
# Out:
# <AxesSubplot: xlabel='Dentist', ylabel='Response'>

# %%
formula='Response ~ C(Dentist) + C(Method) + C(Alloy) + C(Dentist):C(Method)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#                         df         sum_sq        mean_sq          F  \
# C(Dentist)             4.0  157794.555556   39448.638889   4.012170
# C(Method)              2.0  593427.488889  296713.744444  30.177618
# C(Alloy)               1.0  105815.511111  105815.511111  10.762090
# C(Dentist):C(Method)   8.0  306471.844444   38308.980556   3.896260
# Residual              74.0  727586.155556    9832.245345        NaN
#
#                             PR(>F)
# C(Dentist)            5.325926e-03
# C(Method)             2.607075e-10
# C(Alloy)              1.581576e-03
# C(Dentist):C(Method)  7.001897e-04
# Residual                       NaN

# %%
formula='Response ~ C(Dentist) + C(Method) + C(Alloy)+ C(Dentist):C(Method)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)

# %%
formula='Response ~ C(Method) + C(Temp)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#              df        sum_sq        mean_sq          F        PR(>F)
# C(Method)   2.0  5.934275e+05  296713.744444  20.749383  4.588145e-08
# C(Temp)     2.0  8.217802e+04   41089.011111   2.873381  6.201275e-02
# Residual   85.0  1.215490e+06   14299.882876        NaN           NaN

# %%
sns.pointplot(x='Method', y='Response', data=df2, hue='Temp', errorbar=None)
# Out:
# <AxesSubplot: xlabel='Method', ylabel='Response'>

# %%
formula='Response ~ C(Dentist) + C(Alloy) + C(Dentist):C(Alloy)'
model=ols(formula, df2).fit()
aov_table=anova_lm(model)
print(aov_table)
# Out:
#                        df        sum_sq        mean_sq         F    PR(>F)
# C(Dentist)            4.0  1.577946e+05   39448.638889  1.945921  0.110853
# C(Alloy)              1.0  1.058155e+05  105815.511111  5.219663  0.024982
# C(Dentist):C(Alloy)   4.0  5.687044e+03    1421.761111  0.070133  0.990853
# Residual             80.0  1.621798e+06   20272.480556       NaN       NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Dentist   90 non-null     int64
#  1   Method    90 non-null     int64
#  2   Alloy     90 non-null     int64
#  3   Temp      90 non-null     int64
#  4   Response  90 non-null     int64
# dtypes: int64(5)
# memory usage: 3.6 KB

# %%
df2.describe()
# Out:
#          Dentist     Method      Alloy         Temp     Response
# count  90.000000  90.000000  90.000000    90.000000    90.000000
# mean    3.000000   2.000000   1.500000  1600.000000   741.777778
# std     1.422136   0.821071   0.502801    82.107083   145.767845
# min     1.000000   1.000000   1.000000  1500.000000   289.000000
# 25%     2.000000   1.000000   1.000000  1500.000000   698.000000
# 50%     3.000000   2.000000   1.500000  1600.000000   767.000000
# 75%     4.000000   3.000000   2.000000  1700.000000   824.000000
# max     5.000000   3.000000   2.000000  1700.000000  1115.000000

# %%
sns.histplot(df2["Response"], kde=True, stat="density")
# Out:
# <AxesSubplot: xlabel='Response', ylabel='Density'>

# %%
# Out:
# TtestResult(statistic=-36.73038540665224, pvalue=8.7328623006375e-60, df=99)

# %%
from statsmodels.formula.api import ols      # For n-way ANOVA
from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA
sns.catplot(data=df, x="Alloy", y="Response", kind="box")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 3
#       1 from statsmodels.formula.api import ols      # For n-way ANOVA
#       2 from statsmodels.stats.anova import _get_covariance,anova_lm # For n-way ANOVA
# ----> 3 sns.catplot(data=df, x="Alloy", y="Response", kind="box")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3187, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3185 p = _CategoricalPlotter()
#    3186 p.require_numeric = plotter_class.require_numeric
# -> 3187 p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3188 if (
# ...

# %%
(56+24)/145
# Out:
# 0.5517241379310345
